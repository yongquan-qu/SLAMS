# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt 
import matplotlib.ticker as ticker
import seaborn as sns
from tqdm import tqdm
import pandas as pd
import numpy as np

# %% [markdown]
# ### Ablation 1: Varying coarseness of observation

# %%
## CONCLUSION: Diffusion in the latent space tends to be more stable than that in the physical space 
## with more perturbation in the observation domain (i.e., increasing coarseness)

model_names = ['sda_0', 'lsda_1']
model_labels = ['Unimodal Pixel', 'Multimodal Latent']
params = [10, 50, 100, 200, 300, 500, 700, 850, 925, 1000]
coarsening_factors = [4, 8, 12, 15, 20]
n_params = 10
sigma = 0.1

f, ax = plt.subplots(2, 5, figsize=(16, 4), sharex=True) 

for param_idx in range(n_params):
    row = param_idx // 5 
    col = param_idx % 5  
    for model_idx, model_name in enumerate(model_names):
        df = pd.read_csv(f'../docs/{model_name}/wasserstein_coarse.csv')
        line, = ax[row, col].plot(coarsening_factors, df.iloc[param_idx].values, label=f'{model_labels[model_idx]}', linewidth=4)
        ax[row, col].plot(coarsening_factors, df.iloc[param_idx].values, 'o', markersize=10, color=line.get_color())
    
    ax[row, col].set_title(f't@{params[param_idx]}hpa')

plt.legend()
plt.tight_layout()
f.savefig('../docs/all/wasserstein_coarse.pdf', dpi=300, bbox_inches='tight')

# %%
## CONCLUSION: Further emphasizing the stability of various cases of  
## modality in the latent space: diffusion in the latent space is more stable than in the physical space

model_names = ['sda_0', 'lsda_1', 'lsda_2']
model_labels = ['Pixel-Space', 'Latent \n(in-situ)', 'Latent \n(in-situ + ex-situ)'] 
params = [10, 50, 100, 200, 300, 500, 700, 850, 925, 1000]
sigma = 0.1

# Adjust subplot layout to 2 rows and 5 columns
f, ax = plt.subplots(2, 5, figsize=(16, 4), sharey=True, sharex=True)

for param_idx, param in enumerate(params):
    row = param_idx // 5  # Determine row for the subplot
    col = param_idx % 5   # Determine column for the subplot
    
    # Plot the value for the Physical model as a vertical line
    df_physical = pd.read_csv(f'../docs/sda_0/wasserstein_coarse.csv')
    ax[row, col].axvline(df_physical.iloc[param_idx, -1], color='black', linestyle='--', linewidth=4, label='Pixel-Space')

    # Plot bars for the other models in the specified order
    for model_idx, model_name in enumerate(model_names[1:]):  # Skip 'sda_0' (Physical) for bar plotting
        df = pd.read_csv(f'../docs/{model_name}/wasserstein_coarse.csv')
        bar_position = 1 - model_idx  # Reverse the order for bar plotting
        ax[row, col].barh(bar_position, df.iloc[param_idx, -1], edgecolor='black', alpha=0.7)

    # Configure subplot aesthetics
    ax[row, col].set_title(f't@{param}hpa')
    ax[row, col].set_xlabel('Wasserstein distance')
    ax[row, col].xaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))

# Post-processing to set y-ticks and labels correctly
model_bar_labels = model_labels[1:] 
ax[0, 0].set_yticks(range(len(model_labels[1:])))
ax[0, 0].set_yticklabels(model_bar_labels[::-1])

plt.tight_layout()
plt.legend()
f.savefig('../docs/all/ablation_coarse.pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Ablation 2: Varying noise level in observation

# %%
## CONCLUSION: Diffusion in the latent space tends to be more stable than that in the physical space 
## with more perturbation in the observation domain (i.e., increasing noisiness)

model_names = ['sda_0', 'lsda_1']
model_labels = ['Unimodal Pixel', 'Multimodal Latent']
params = [10, 50, 100, 200, 300, 500, 700, 850, 925, 1000]
sigma_sqs = [0.5, 1.0, 2.0, 4.0]
n_params = 10

f, ax = plt.subplots(2, 5, figsize=(16, 4), sharex=True) 

for param_idx in range(n_params):
    row = param_idx // 5 
    col = param_idx % 5  
    for model_idx, model_name in enumerate(model_names):
        df = pd.read_csv(f'../docs/{model_name}/wasserstein_noise.csv')
        line, = ax[row, col].plot(sigma_sqs, df.iloc[param_idx].values, label=f'{model_labels[model_idx]}', linewidth=4)
        ax[row, col].plot(sigma_sqs, df.iloc[param_idx].values, 'o', markersize=10, color=line.get_color()) 
    
    ax[row, col].set_title(f't@{params[param_idx]}hpa')

plt.tight_layout()
plt.legend()
f.savefig('../docs/all/wasserstein_noise.pdf', dpi=300, bbox_inches='tight')

# %%
## CONCLUSION: Further emphasizing the stability of various cases of  
## modality in the latent space: diffusion in the latent space is more stable than in the physical space

model_names = ['sda_0', 'lsda_1', 'lsda_2']
model_labels = ['Pixel-Space', 'Latent \n(in-situ)', 'Latent \n(in-situ + ex-situ)'] 
params = [10, 50, 100, 200, 300, 500, 700, 850, 925, 1000]
sigma_sqs = [0.5, 1.0, 2.0, 4.0]

# Adjust subplot layout to 2 rows and 5 columns
f, ax = plt.subplots(2, 5, figsize=(16, 4), sharey=True, sharex=True)

for param_idx, param in enumerate(params):
    row = param_idx // 5  # Determine row for the subplot
    col = param_idx % 5   # Determine column for the subplot
    
    # Plot the value for the Physical model as a vertical line
    df_physical = pd.read_csv(f'../docs/sda_0/wasserstein_noise.csv')
    ax[row, col].axvline(df_physical.iloc[param_idx, -1], color='black', linestyle='--', linewidth=4, label='Pixel-Space')

    # Plot bars for the other models in the specified order
    for model_idx, model_name in enumerate(model_names[1:]):  # Skip 'sda_0' (Physical) for bar plotting
        df = pd.read_csv(f'../docs/{model_name}/wasserstein_noise.csv')
        bar_position = 1 - model_idx  # Reverse the order for bar plotting
        ax[row, col].barh(bar_position, df.iloc[param_idx, -1], edgecolor='black', alpha=0.7)

    # Configure subplot aesthetics
    ax[row, col].set_title(f't@{param}hpa')
    ax[row, col].set_xlabel('Wasserstein distance')
    ax[row, col].xaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))

# Post-processing to set y-ticks and labels correctly
model_bar_labels = model_labels[1:] 
ax[0, 0].set_yticks(range(len(model_labels[1:])))
ax[0, 0].set_yticklabels(model_bar_labels[::-1])

plt.tight_layout()
plt.legend()
f.savefig('../docs/all/ablation_noise.pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Ablation 3: Varying sparsity in observation

# %%
## CONCLUSION: Diffusion in the latent space tends to be more stable than that in the physical space 
## with more perturbation in the observation domain (i.e., increasing sparsity)

model_names = ['sda_0', 'lsda_1']
model_labels = ['Unimodal Pixel', 'Multimodal Latent']
params = [10, 50, 100, 200, 300, 500, 700, 850, 925, 1000]
sparsity_factors = [4.0, 8.0, 12.0, 16.0]
n_params = 10

f, ax = plt.subplots(2, 5, figsize=(16, 4), sharex=True) 

for param_idx in range(n_params):
    row = param_idx // 5 
    col = param_idx % 5  
    for model_idx, model_name in enumerate(model_names):
        df = pd.read_csv(f'../docs/{model_name}/wasserstein_sparse.csv')
        line, = ax[row, col].plot(sparsity_factors, df.iloc[param_idx].values, label=f'{model_labels[model_idx]}', linewidth=4)
        ax[row, col].plot(sparsity_factors, df.iloc[param_idx].values, 'o', markersize=10, color=line.get_color()) 
    
    ax[row, col].set_title(f't@{params[param_idx]}hpa')

plt.tight_layout()
plt.legend()
f.savefig('../docs/all/wasserstein_sparse.pdf', dpi=300, bbox_inches='tight')

# %%
## CONCLUSION: Further emphasizing the stability of various cases of  
## modality in the latent space: diffusion in the latent space is more stable than in the physical space

model_names = ['sda_0', 'lsda_1', 'lsda_2']
model_labels = ['Pixel-Space', 'Latent \n(in-situ)', 'Latent \n(in-situ + ex-situ)'] 
params = [10, 50, 100, 200, 300, 500, 700, 850, 925, 1000]

# Adjust subplot layout to 2 rows and 5 columns
f, ax = plt.subplots(2, 5, figsize=(16, 4), sharey=True, sharex=True)

for param_idx, param in enumerate(params):
    row = param_idx // 5  # Determine row for the subplot
    col = param_idx % 5   # Determine column for the subplot
    
    # Plot the value for the Physical model as a vertical line
    df_physical = pd.read_csv(f'../docs/sda_0/wasserstein_sparse.csv')
    ax[row, col].axvline(df_physical.iloc[param_idx, -1], color='black', linestyle='--', linewidth=4, label='Pixel-Space')

    # Plot bars for the other models in the specified order
    for model_idx, model_name in enumerate(model_names[1:]):  # Skip 'sda_0' (Physical) for bar plotting
        df = pd.read_csv(f'../docs/{model_name}/wasserstein_sparse.csv')
        bar_position = 1 - model_idx  # Reverse the order for bar plotting
        ax[row, col].barh(bar_position, df.iloc[param_idx, -1], edgecolor='black', alpha=0.7)

    # Configure subplot aesthetics
    ax[row, col].set_title(f't@{param}hpa')
    ax[row, col].set_xlabel('Wasserstein distance')
    ax[row, col].xaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))

# Post-processing to set y-ticks and labels correctly
model_bar_labels = model_labels[1:] 
ax[0, 0].set_yticks(range(len(model_labels[1:])))
ax[0, 0].set_yticklabels(model_bar_labels[::-1])

plt.tight_layout()
plt.legend()
f.savefig('../docs/all/ablation_sparse.pdf', dpi=300, bbox_inches='tight')
